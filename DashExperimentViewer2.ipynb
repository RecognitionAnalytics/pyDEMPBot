# %%
from dashboard import Dashboard
from IPython.display import display, HTML

dashboard = Dashboard( )        
dashboard.CreateIVDash()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Loading from : //biod2100/DataFolder/W093/D2
# Loading from : //biod2100/DataFolder/W094/D1
# [2025-02-25 08:40:11,238] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\DempBot\DataBot\Lib\site-packages\flask\app.py", line 880, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\DempBot\DataBot\Lib\site-packages\flask\app.py", line 865, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\DempBot\DataBot\Lib\site-packages\dash\dash.py", line 1373, in dispatch
#     ctx.run(
# ...

# %%
#display(HTML("<style>.container { height:1800px !important; }</style>"))
#display(HTML("<style>.output_result { height:1800px !important; }</style>"))
#display(HTML("""<style>
#.jp-OutputArea-output { height:1800px  !important; }
#.jp-Cell-outputArea { height:1800px  !important; }
#.jp-OutputArea   { height:1800px  !important; }            
#             </style>"""))
#lm-Widget jp-OutputArea
